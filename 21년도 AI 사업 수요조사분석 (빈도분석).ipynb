# %%
import numpy as np

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt

# %%
f=open('all.txt','r',encoding='UTF-8')

lines = f.read()
f.close()

# %% [markdown]
# * read() : 텍스트 파일을 read로 읽어오는 경우 str파일을 생성한다.
# * readlines( ) : 텍스트 파일을 readlines로 읽어오는 경우 list 파일을 생성한다.

# %%
lines
# Out:
# '\n다중 생체 지표 기반의 중증 응급환자 인공지능 자동분류 키오스크 및 이상 징후 원격 모니터링 시스템 개발 - 중증 환자 및 응급 환자 자동 분류 키오스크 개발   - 인공지능 자동 판단 및 분류 알고리즘 개발 - 다중 생체 지표 데이터베이스화 - 키오스크 및 모바일 감시장치 데이터 병원 EMR 연동 준비- 의료기기 신의료기술 평가, 보험등재, 투자유치 - 다기관 임상시험, 사업화\n근전외선을 이용한 기도흡인평가 시스템 기도흡인 관련 의료영상확보\n치매 진단 및 치료기술 개발 1단계 3년: 수집 및 플랫폼 개발; 2단계 4년: 임상시험 및 인허가 진행\n개인유전체 서열정보와 인공지능(딥러닝)을 이용하여 만성질환/표현형 유전체예측/질병 예측 기술의 개발 질병청에서 분양(예정)중인 데이터는 6만명 수준이나 현재 DNALink에서 용역으로 생산한 데이터는 그보다 크다고 생각이 됨. 한국인 모델에 대하여는 질병청에 분양하는 데이터를 활용하고 서양인 모델에 대하여는 UKBB에서 분양받은 데이터를 활용함. 딥러닝 모델의 개발에는 약 10만명 수준의 데이터가 필요하며, 검증은 독립된 코호트 (임상의 협업)로 실제 만성질환 환자에 대한 후향적 검증 및 전향적 임상 적용을 동시에 수행함.\ngenomics, transcriptomics 와 antibody library 에 따른 COVID-19 감염 및 예후. 수집한 샘플의 genomic, transcriptomic library 생성 및 분석. 감염자들은 체혈을 할텐데, antibody library 분석 까지 이어짐(B-cell, T-cell)\n심방세동 환자에서 심전도 이미지를 이용하ㄴ 예후 예측 모델 개발 1년차:데이터 확보,이미지 분석2:결과 분석,발표\n직립상태의 척추 X-ray 데이터(골반포함)를 사용한, 척추 상태(비틀림, 휘어짐) 측정 1. 직립 2차원 X-RAY를 사용하여, 앞쪽 이미지와 옆쪽 이미지를 사용하면, 특정한 위치에 대한 정확한 추출(딥러닝 사용사용하여), 2. 추출된 위치를, 척추와 골반의 기본모형에 적용(Registration)하면, 서있는 상태의 3차원 척추와 골반의 뒤틀림과 변형을 자동으로 판독,3. Cohort 추적을 하게 되어, 상관 관계(또는 확률 분포)를 추정4. 현재 척추나 골반의 상태를 가지고, 추후 발병에 대한 예측\n응급실에 내원한 소아 골절 환자의 진단과 치료 방침 결정을 보조하기 위한 영상데이터와 관련 인공지능 알고리즘 개발 1년차: Data 공유 플랫폼 구축 및 Data수집 개시2년차: Data 수집 및 복수의 전문의에 의한 라벨링, 기수집된 학습 Data를 이용한 알고리즘 탐색개발3년차: Data수집 완료, 라벨링 완료, Data를 이용한 알고리즘 개발 완료4년차: 라벨링된 Dataset 표준화 및 플랫폼 공유, 외부 Data를 이용한 알고리즘 검증\n질환 특이적인 면역 레퍼토어 데이터 수집 및 분석 활용 1. 환자 BCR/TCR 데이터 확보, 2. 확보된 데이터를 기반으로 한 진단 기준 설립, 3. 기존 gold standard 방법과 해당 진단 방법과의 비교 분석, 4. 추적관찰 진행\nAid-AI module for differential diagnosis of gynecologic cancer Gynecologic cancer의 digital pathology imaging을 일차적으로 이용하여 학습함.Whole scan imaging을 이용한 data로 이차학습을 검증. 두개이상의 기관에서 aiding AI module을 조정하여 실제 임상의학 영역에 이용될 module아르개발함\nCT 결과를 통한 폐기능 예측 모델 개발 Training, validation set을 통해서 폐기능의 예측값과 실제 값과 CT에서의 예측값을 비교 CT를 통한 폐기능 예측모델 개발\n다중 오믹스 데이터의 통합적 분석을 통한 췌장암 생존율 향상 전략 개발 1년차 -  췌장암 환자 대규모 통합 코호트 구축 (임상정보+병리정보+영상정보)2년차 - 인체유래물 은행을 통한 대규모 췌장암 검체 확보 및 염기 서열 시퀀싱3년차 - 다중오믹스 데이터 레이어 통합 및 중요 임상 포인트 예측 모델 구축 (1)4년차 - 다중오믹스 데이터 레이어 통합 및 중요 임상 포인트 예측 모델 구축 (2)5년차 -  연구개발의 성과에 대한 조기 임상시험을 통한 유효성 확인\nCT이미지 딥 러닝을 통한 폐암 예측 알고리즘 개발 CT상 결절이 진단된 환자들의 CT영상\n치아 및 잇몸 이미지 분석 AI 솔루션 개발 1년차  : 1) 구강 전면부 이미지 수집 및 labeling2) 치주과 전문의 labeling 데이터 검수2년차 : 1) 인공신경망 구축 및 학습2) SDK 개발 및 서버 분석 시스템 구축, 테스트 앱 개발 \n암환자 조직별 단백질 발현 양 비교 기존 암조직별 단백질체 데이터 베이스 확보\n유전성 암 선별과제, 부인암 예후 예측, 양성종양 및 악성종양감별 과제 1. 다기관 자료확보2. Algorithm 구축 확인\n인공지능기반 혈관중재수술로봇시스템 혈관의 막힘 여부, 암세포 형성 여부를 파악하기 위하여 다양한 질환을 가지고 있는 환자의 혈관 데이터 획득\n이상적인 인공관절 치환물 위치를 설정하기 위한 인공지능을 이용한 3차원 수술전 계획용 소프트웨어의 개발 개발 단계는 2트랙으로 진행한개의 트랙은 수술계획 수립과 이를 출력하기 위한 SW개발다른 한개의 트랙은 이 수술 계획 수립을 위한 해부학적 구조와 상관관계에 대한 AI 학습과 인공관절 치환술 시뮬레이션상에서 최적의 운동범위와 영상학적 결과를 얻기 위한 절골술위치/각도, 인공관절 치환물 크기/위치/각도에 대한 AI 학습. 그리고 이러한 학습결과의 validation임.1단계: 환자의 CT 데이터 분석과 3D reconstruction, 인공관절 치환물 스캐닝 및 구조화, 두 데이터의 통합 및 이러한 인공관절 치환물 삽입을 시뮬레이션 할 수 있는 SW의 개발2단계: 견갑골과 상완골의 해부학적 구조 및 상관관계에 대한 AI학습. AI를 이용한 인공관절 삽입을 위한 절골술 및 골소실을 보정한 골준비 시뮬레이션, 인공관절 치환술 시뮬레이션. AI를 이용한 시뮬레이션상의 운동범위 추정, 각 절골술과 시뮬레이션 된 인공관절 치환술 상태에서의 최대 운동각도 학습 및 이의 validation3단계 SW상에서 AI학습 결과를 구현하기 위한 통합4단계 실제 수술 환자를 대상으로 SW의 결정된 인공관절 치환술을 위한 수술가이드 제작 및 적용. 그리고 이 결과의 검증\n소아정신과 진단 및 예후를 예측하는 AI 연구 진료실, 행동 치료실, 그리고 평소 각 가정에서의 행동 데이터를 수집. 이를 AI가 분석한 결과와 전문의가 기존의 정립된 방식으로 진단한 결과를 비교함으로써 AI 학습과 검증을 진행.\n암환자 관련 병원에서 원천자료의 정확성\n안구질환 예방을 위한 진단시스템 개발  대상 안구질환의 치료 목적으로 내원 환자의 치료 및 치료 경과별 영상데이터 등 확보환자별 기저질환, 치료제, 보조제 등 복용 정보를 확보하고 질환 진행과 상관관계 검증안구질환별 영상데이터에 근거한 진단시스템 개발 및 검증\n퇴행성 뇌신경 장애 극복을 위한 신경신호를 이용한 지능형 인체 증강 기술 개발 1차년. 정밀 신경신호 계측을 위한 신경 보철 장치 및 데이터 획득2차년. 대뇌/말초 신경신호를 이용한 고 정밀의 의도 검출/분석 AI 소프트웨어 구축3차년. 사람-기계 인터페이스를 위한 AI 소프트웨어와 하드웨어 통합\n의약품 레이블 정보를 활용한 네트워크 기반의 신약재창출 모델 개발 약물유사도 측정을 위한 다양한 종류의 데이터베이스 조사 및 정보 수집의료용어 데이터베이스를 활용하여 약물 사전을 구성약물유사도 측정을 위하여 의약품 레이블 정보를 수집이질적 데이터베이스로부터 확보한 약물/적응증유사도 정보를 통합유사도를 기준으로 군집화(clustering)를 실시하여 유사도 표현방식을 최적화랜덤 워크(Random Walk With Restart) 알고리즘을 통해 이질적 네트워크 간 정보를 통합적응증 내 효과 수준을 반영하기 위한 효능/안전성 지표 개발약물/적응증유사도와 약물-적응증 연관성을 활용해 이분(bipartite) 네트워크 구성약물/적응증유사도 정보를 다양한 객체 ...

# %%
type(lines)
# Out:
# str

# %%
from konlpy.tag import Hannanum
hannanum=Hannanum()

# %%
nouns=hannanum.nouns(lines)

# %% [markdown]
# * read로 읽어온 텍스트 파일의 경우 각 문장간에 별도의 리스트 구분을 하지 않은 str형태의
# * 파일을 생성한다. 이렇게 통으로 생성된 파일의 경우 별도의 dataset[]을 만들어 append하는것(네트워크분석 처럼 - 이 경우 2차원 리스트 생성)
# * 이 아니라 그냥 형태소 분석(파일 전체를 분석기에 넣음)을 진행하면 문장간 구분이 없는(리스트 한 칸 안에 하나의 문장 결과가 아닌 모든 단어들이 하나의 리스트 한칸에 들어있는 - 1차원 리스트 형태) 형태소분석 결과가 생성된다.

# %%
nouns
# Out:
# ['다중',
#  '생체',
#  '지표',
#  '기반',
#  '중증',
#  '응급환자',
#  '인공지능',
#  '자동분류',
#  '키오스크',
#  '이상',
#  '징후',
#  '원격',
#  '모니터링',
#  '시스템',
#  '개발',
#  '중증',
#  '환자',
#  '응급',
#  '환자',
#  '자동',
#  '분류',
#  '키오스크',
#  '개발',
#  '인공지능',
#  '자동',
#  '판단',
#  '분류',
#  '알고리즘',
#  '개발',
#  '다중',
#  '생체',
#  '지표',
#  '데이터베이스화',
#  '키오스크',
#  '모바',
#  '감시장치',
#  '데이터',
#  '병원',
#  '연동',
#  '준비',
#  '의료기',
#  '의료기술',
#  '평',
#  '보험등재',
#  '투자유치',
#  '다기관',
#  '임상시험',
#  '사업화',
#  '근전외선',
#  '이용',
#  '기도흡인평가',
#  '시스템',
#  '기도흡인',
#  '관련',
#  '의료영상확보',
#  '치매',
#  '치료기술',
#  '개발',
#  '1단계',
#  '3년',
#  '수집',
#  '플랫폼',
#  '개발;',
#  '2단계',
#  '4년',
#  '임상시험',
#  '인허가',
#  '진행',
#  '개인유전체',
#  '서열정보',
#  '인공지능(딥러닝)',
#  '이용',
#  '만성질환',
#  '표현형',
#  '예측',
#  '기술',
#  '개발',
#  '질병청',
#  '분양(예정)중',
#  '데이터',
#  '6만명',
#  '수준',
#  '현재',
#  '용역',
#  '생산',
#  '데이터',
#  '그',
#  '생각',
#  '한국인',
#  '모델',
#  '질병청',
#  '분양',
#  '데이터',
#  '활용',
#  '서양',
#  '모델',
#  '분양',
#  '데이터',
#  '활용',
#  '딥러닝',
#  '모델',
#  '개발',
#  '약',
#  '10만명',
#  '수준',
#  '데이터',
#  '필요',
#  '검증',
#  '독립',
#  '코호트',
#  '임상',
#  '협업',
#  '실제',
#  '만성질환',
#  '환자',
#  '후향적',
#  '검증',
#  '전향적',
#  '임상',
#  '적용',
#  '수행',
#  '19',
#  '감염',
#  '예후',
#  '수집',
#  '샘플',
#  '생성',
#  '분석',
#  '감염자들',
#  '체혈',
#  '분석',
#  '심방세동',
#  '환자',
#  '심전도',
#  '이미지',
#  '이용',
#  '예후',
#  '예측',
#  '모델',
#  '개발',
#  '1년차:데이터',
#  '확보,이미지',
#  '분석2:결',
#  '분석',
#  '발표',
#  '직립상태',
#  '척추',
#  '데이터(골반포함)',
#  '사용',
#  '척추',
#  '상태(비틀림,',
#  '측정',
#  '1.',
#  '직립',
#  '2차원',
#  '사용',
#  '앞쪽',
#  '이미지',
#  '옆쪽',
#  '이미지',
#  '사용',
#  '특정',
#  '위치',
#  '정확',
#  '추출(딥러닝',
#  '사용사용',
#  '2.',
#  '추출',
#  '위치',
#  '척추',
#  '골반',
#  '기본모형',
#  '적용(Registration)하면,',
#  '상태',
#  '3차원',
#  '척추',
#  '골반',
#  '변형',
#  '자동',
#  '판독',
#  '3',
#  '추적',
#  '상관',
#  '관계(또',
#  '확률',
#  '분포',
#  '추정4',
#  '척추',
#  '골반',
#  '상태',
#  '발병',
#  '예측',
#  '응급실',
#  '내원한',
#  '소아',
#  '골절',
#  '환자',
#  '진단',
#  '치료',
#  '방침',
#  '결정',
#  '보조',
#  '영상데이터',
#  '관련',
#  '인공지능',
#  '알고리즘',
#  '개발',
#  '1년차:',
#  '공유',
#  '플랫폼',
#  '구축',
#  'Data수집',
#  '개시2년차:',
#  '수집',
#  '복수',
#  '전문의',
#  '라벨링',
#  '기수집',
#  '학습',
#  '이용',
#  '알고리즘',
#  '탐색개발3년차:',
#  'Data수집',
#  '완료',
#  '라벨링',
#  '완료',
#  '이용',
#  '알고리즘',
#  '개발',
#  '완료4년차:',
#  '라벨링',
#  '표준화',
#  '플랫폼',
#  '공유',
#  '외부',
#  '이용',
#  '알고리즘',
#  '검증',
#  '질환',
#  '특이적',
#  '면역',
#  '레퍼토',
#  '데이터',
#  '수집',
#  '분석',
#  '활용',
#  '1.',
#  '환자',
#  '데이터',
#  '확보',
#  '2.',
#  '확보',
#  '데이터',
#  '기반',
#  '기준',
#  '설립',
#  '3.',
#  '기존',
#  '방법',
#  '해당',
#  '방법',
#  '비교',
#  '분석',
#  '4.',
#  '추적관찰',
#  '진행',
#  '일차적',
#  '이용',
#  '학습',
#  '이용',
#  '이차학습',
#  '검증',
#  '두개이상',
#  '기관',
#  '조정',
#  '실제',
#  '임상의학',
#  '영역',
#  '이용',
#  'module아르개발함',
#  '결과',
#  '폐기능',
#  '예측',
#  '모델',
#  '개발',
#  '폐기능',
#  '예측값',
#  '실제',
#  '값',
#  '예측값',
#  '비교',
#  '폐기능',
#  '예측모델',
#  '개발',
#  '다중',
#  '오믹스',
#  '데이터',
#  '통합적',
#  '분석',
#  '췌장암',
#  '생존율',
#  '향상',
#  '전략',
#  '개발',
#  '1년차',
#  '췌장암',
#  '환자',
#  '대규모',
#  '통합',
#  '코호트',
#  '구축',
#  '(임상정보+병리정보+영상정보)2년차',
#  '인체유래물',
#  '은행',
#  '대규모',
#  '췌장암',
#  '검체',
#  '확보',
#  '염기',
#  '서열',
#  '시퀀싱3년차',
#  '다중오믹스',
#  '데이터',
#  '레',
#  '통합',
#  '중요',
#  '임상',
#  '포인트',
#  '예측',
#  '모델',
#  '구축',
#  '(1)4년차',
#  '다중오믹스',
#  '데이터',
#  '레',
#  '통합',
#  '중요',
#  '임상',
#  '포인트',
#  '예측',
#  '모델',
#  '구축',
#  '(2)5년차',
#  '연구개발',
#  '성과',
#  '조',
#  '임상시험',
#  '유효성',
#  '확인',
#  'CT이미지',
#  '딥',
#  '러닝',
#  '폐암',
#  '예측',
#  '알고리즘',
#  '개발',
#  '상',
#  '결절',
#  '진단',
#  '환자들',
#  '영상',
#  '치아',
#  '잇몸',
#  '이미지',
#  '분석',
#  '솔루션',
#  '개발',
#  '1년차',
#  '1',
#  '구강',
#  '전면부',
#  '이미지',
#  '수집',
#  'labeling2)',
#  '치주',
#  '전문',
#  '데이터',
#  '검수2년차',
#  '1',
#  '인공신경망',
#  '구축',
#  '학습2)',
#  '개발',
#  '서버',
#  '분석',
#  '시스템',
#  '구축',
#  '테스트',
#  '앱',
#  '개발',
#  '암환자',
#  '조직별',
#  '단백질',
#  '발현',
#  '양',
#  '비교',
#  '기존',
#  '암조직별',
#  '단백질체',
#  '데이터',
#  '베이스',
#  '확보',
#  '유전성',
#  '선별과제',
#  '부인암',
#  '예후',
#  '예측',
#  '양성종양',
#  '악성종양감별',
#  '과제',
#  '1.',
#  '다기관',
#  '자료확보2',
#  '구축',
#  '확인',
#  '인공지능기반',
#  '혈관중재수술로봇시스템',
#  '혈관',
#  '여부',
#  '암세포',
#  '형성',
#  '여부',
#  '파악',
#  '다양',
#  '질환',
#  '환자',
#  '혈관',
#  '데이터',
#  '획득',
#  '이상적',
#  '인공관절',
#  '치환물',
#  '위치',
#  '설정',
#  '인공지능',
#  '이용',
#  '3차원',
#  '수술전',
#  '계획용',
#  '소프트웨어',
#  '개발',
#  '개발',
#  '단계',
#  '2트랙',
#  '진행한개',
#  '트랙',
#  '수술계획',
#  '수립',
#  '이',
#  '출력',
#  'SW개발다른',
#  '한개',
#  '트랙',
#  '수술',
#  '계획',
#  '수립',
#  '해부학적',
#  '구조',
#  '상관관계',
#  '학습',
#  '인공관절',
#  '치환술',
#  '시뮬레이션상',
#  '최적',
#  '운동범위',
#  '영상학적',
#  '결과',
#  ',',
#  '인공관절',
#  '치환물',
#  '위치',
#  '각도',
#  '학습',
#  '학습결과',
#  '1단계:',
#  '환자',
#  '데이터',
#  '분석',
#  '3D',
#  '인공관절',
#  '치환물',
#  '스캐닝',
#  '구조화',
#  '두',
#  '데이터',
#  '통합',
#  '인공관절',
#  '치환물',
#  '삽입',
#  '시뮬레이션',
#  '수',
#  '개발2단계:',
#  '견갑골',
#  '상완골',
#  '해부학적',
#  '구조',
#  '상관관계',
#  'AI학습',
#  '이용',
#  '인공관절',
#  '삽입',
#  '절골술',
#  '골소실',
#  '보정',
#  '골준비',
#  '시뮬레이션',
#  '인공관절',
#  '치환술',
#  '시뮬레이션',
#  '이용',
#  '시뮬레이션상',
#  '운동범위',
#  '추정',
#  '절골술',
#  '시뮬레이션',
#  '인공관절',
#  '치환술',
#  '상태',
#  '최대',
#  '운동각도',
#  '학습',
#  '이',
#  'validation3단계',
#  '상',
#  'AI학습',
#  '결과',
#  '구현',
#  '통합4단계',
#  '실제',
#  '수술',
#  '환자',
#  '대상',
#  '결정',
#  '인공관절',
#  '치환술',
#  '수술가이드',
#  '제작',
#  '적용',
#  '결과',
#  '검증',
#  '소아정신과',
#  '예후',
#  '예측',
#  '연구',
#  '진료실',
#  '행동',
#  '치료',
#  '평소',
#  '가정',
#  '행동',
#  '데이터',
#  '수집',
#  '이',
#  '분석',
#  '결과',
#  '전문의',
#  '기존',
#  '정립',
#  '방식',
#  '한',
#  '결과',
#  '비교',
#  '학습',
#  '검증',
#  '진행',
#  '암환자',
#  '관련',
#  '병원',
#  '원천자료',
#  '정확성',
#  '안구질환',
#  '예방',
#  '진단시스템',
#  '개발',
#  '대상',
#  '안구질환',
#  '치료',
#  '목적',
#  '내원',
#  '환자',
#  '치료',
#  '치료',
#  '경과별',
#  '영상데이터',
#  '등',
#  '확보환자별',
#  '기저질환',
#  '치료제',
#  '보조제',
#  '등',
#  '복용',
#  '정보',
#  '확보',
#  '질환',
#  '진행',
#  '상관관계',
#  '검증안구질환별',
#  '영상데이터',
#  '근거한',
#  '진단시스템',
#  '개발',
#  '검증',
#  '퇴행성',
#  '뇌신경',
#  '장애',
#  '극복',
#  '신경신호',
#  '이용',
#  '지능형',
#  '인체',
#  '증강',
#  '기술',
#  '개발',
#  '1차년',
#  '정밀',
#  '신경신호',
#  '계측',
#  '신경',
#  '보철',
#  '장치',
#  '데이터',
#  '획득2차년',
#  '대뇌',
#  '말초',
#  '신경신호',
#  '이용',
#  '고',
#  '정밀',
#  '의',
#  '검출',
#  '분석',
#  '소프트웨어',
#  '구축3차년',
#  '사람',
#  '기계',
#  '인터페이스',
#  '소프트웨어',
#  '하드웨어',
#  '통합',
#  '의약품',
#  '레이블',
#  '정보',
#  '활용',
#  '네트워크',
#  '기반',
#  '약재창출',
#  '모델',
#  '개발',
#  '약물유사',
#  '측정',
#  '다양한',
#  '종류',
#  '데이터베이스',
#  '조사',
#  '정보',
#  '수집의료용어',
#  '데이터베이스',
#  '활용',
#  '약물',
#  '사전',
#  '구성약물유사',
#  '측정',
#  '의약품',
#  '레이블',
#  '정보',
#  '수집이질적',
#  '데이터베이스',
#  '확보',
#  '정보',
#  '통합유사도',
#  '기준',
#  '군집화(clustering)',
#  '실시',
#  '유사',
#  '표현방식',
#  '최적화랜덤',
#  '워크(Random',
#  '알고리즘',
#  '이질적',
#  '네트워크',
#  '정보',
#  '통합적응증',
#  '내',
#  '효과',
#  '수준',
#  '반영하기',
#  '효능',
#  '안전성',
#  '지표',
#  '약물',
#  '적응증',
#  '연관성',
#  '활용',
#  '이분(bipartite)',
#  '네트워크',
#  '정보',
#  '다양',
#  '객체',
#  '관계',
#  '표현',
#  '그래프',
#  '이론',
#  '활용',
#  '계산',
#  '가능',
#  '형태',
#  '변환확보',
#  '유사',
#  '연관성',
#  '정보',
#  '결합',
#  '네트워크',
#  '형성',
#  '랜덤',
#  '워크',
#  '알고리즘',
#  '약물',
#  '적응증',
#  '연관성',
#  '예측',
#  '기반',
#  '질병정보',
#  '예측',
#  '신경망',
#  '에측',
#  '접목',
#  '질병',
#  '확산세',
#  '검토',
#  '검사',
#  '활용',
#  '인공지능',
#  '개발',
#  '1차년도',
#  '공유',
#  '부산대병원',
#  '2개',
#  '인공지능',
#  '적용',
#  'test2차년도',
#  '진검학회',
#  '활용위원회',
#  '중심',
#  '20개',
#  '병원',
#  '검사활용도',
#  '관련해',
#  '시범',
#  '운영',
#  '3차년도',
#  '독립형',
#  '적용',
#  '전후',
#  '효과',
#  '분석',
#  '특허출원',
#  'validation완료',
#  '상품',
#  '출시',
#  '염색체',
#  '판독',
#  '의료인공지능기술',
#  '개발',
#  '염색체',
#  '핵형',
#  '분석기',
#  '저장',
#  '염색체',
#  '데이터',
#  '실제',
#  '병리사',
#  '전문의',
#  '판독',
#  '결과',
#  '매칭하',
#  '데이터',
#  '확보',
#  '디지철',
#  '병리영상',
#  '이용',
#  '침윤성',
#  '유방암',
#  '모듈',
#  '개발',
#  '침윤성',
#  '유방암',
#  '병리진단',
#  '디지털',
#  '이미지',
#  '자료',
#  '이용',
#  '종양',
#  '침윤부위',
#  '스크리닝',
#  '수',
#  '개발',
#  '함',
#  '인공지능',
#  '기반',
#  '요천추신경근병증',
#  '치료',
#  '효과',
#  '분석용',
#  '적외선',
#  '열화상',
#  '기',
#  '개발',
#  '1',
#  '데이터셋',
#  '개발',
#  '①',
#  '데이터셋',
#  '구축용',
#  '장비(HW,',
#  '장소',
#  '구축',
#  '병원',
#  '내',
#  '구축',
#  '②',
#  '정상',
#  '데이터셋',
#  '기',
#  '개발',
#  '한국인',
#  '정상',
#  '성인',
#  '하지체열',
#  '참조표준',
#  '데이터',
#  '연구',
#  '변형',
#  '이용',
#  '정상',
#  '성',
#  '954명',
#  '적외선',
#  '체열',
#  '영상',
#  '데이터',
#  '③',
#  '요천추신경근병증',
#  '데이터셋',
#  '데이터',
#  '확보',
#  '연구',
#  '참여',
#  '4개',
#  '이상',
#  '병원',
#  '1년차(6개월)',
#  '각종',
#  '프로토콜',
#  '촬영실',
#  '기',
#  '소급성',
#  '확보',
#  '연구대상자',
#  '모집',
#  '심',
#  '등',
#  '기반',
#  '구축',
#  '작업',
#  '연구',
#  '2',
#  '3년차',
#  '동안',
#  '매년',
#  '병원',
#  '100명',
#  '환자',
#  '데이터',
#  '수집',
#  '예정',
#  '데이터셋:',
#  '최초',
#  '3개년',
#  '약',
#  '1,000명',
#  '요천추신경근병증',
#  '환자',
#  '데(2)',
#  '요천추신경근병증',
#  '진단용',
#  '인공지능',
#  '모델',
#  '개발',
#  '①',
#  '요천추신경근병변',
#  '판별',
#  '촬영',
#  '부위별',
#  '구분',
#  '좌우',
#  '상하',
#  '온도차',
#  '분석',
#  '인공지능',
#  '이용',
#  '알고리즘',
#  '개발',
#  '②',
#  '요천추신경근병증',
#  '진단용',
#  '인공지능',
#  '모델',
#  '개발(3)',
#  '기계학습',
#  '요천추신경근병증',
#  '진단용',
#  '스캐닝',
#  '기술',
#  '개발',
#  '①',
#  '인공지능형',
#  '적외선',
#  '체열',
#  '촬영',
#  '자세별',
#  '스캐닝',
#  '알고리즘',
#  '장치',
#  '개발',
#  '4',
#  '다양한',
#  '환경온도',
#  '적용',
#  '실제',
#  '온도',
#  '검출용',
#  '보정',
#  '최적화',
#  '기술',
#  '개발',
#  '①',
#  '적외선',
#  '카메라',
#  '환경온도',
#  '대응',
#  '실제온도',
#  '최적화',
#  '보정',
#  '기술',
#  '개발(5)',
#  '치료',
#  '전후',
#  '통증',
#  '호전',
#  '여부',
#  '판단',
#  '기술',
#  '개발',
#  '①',
#  '인공지능',
#  '신체',
#  '부위별',
#  '좌우',
#  '상하',
#  '온도차',
#  '이용',
#  '통증',
#  '정도',
#  '구분',
#  '방법',
#  '이용',
#  '②',
#  '최초',
#  '등록',
#  '촬영소견',
#  '치료',
#  '후',
#  '촬영',
#  '소견',
#  '분석',
#  '변화',
#  '통증',
#  '정도',
#  '부위',
#  '평가',
#  '치료',
#  '효과',
#  '여부',
#  '판단',
#  '기술',
#  '개발(6)',
#  '인공지능',
#  '기반',
#  '요천추신경근병증',
#  '치료',
#  '효과',
#  '분석용',
#  '적외선',
#  '체열',
#  '진단기',
#  '개발',
#  '①',
#  '오픈',
#  '프레임워크',
#  '개발',
#  ...]

# %%
type(nouns)
# Out:
# list

# %% [markdown]
# * 1차원 리스트 형태 [ ] 이 안에 모든 단어들이 들어가있음 ( 즉, 문장간의 구분은 없다.)

# %%
import requests
import pandas as pd
from collections import Counter

# %%
word_list = pd.Series(nouns)

# %% [markdown]
# * list 형태를 판다스 시리즈 형태로 변환

# %%
word_list
# Out:
# 0         다중
# 1         생체
# 2         지표
# 3         기반
# 4         중증
#         ...
# 7846      이용
# 7847      예후
# 7848      예측
# 7849    알고리듬
# 7850      개발
# Length: 7851, dtype: object

# %%
result = word_list.value_counts()

# %% [markdown]
# * 판다스에는 value_counts() 메소드가 있음. 사용하면 각 고유값의 개수를 반환

# %%
result
# Out:
# 개발      254
# 데이터     215
# 환자      111
# 분석       99
# 기반       90
#        ...
# 집단        1
# 병상        1
# 실내        1
# 산정        1
# 연동작업      1
# Length: 2365, dtype: int64

# %%
type(result)
# Out:
# pandas.core.series.Series

# %%
result[:30]
# Out:
# 개발      254
# 데이터     215
# 환자      111
# 분석       99
# 기반       90
# 이용       83
# 인공지능     75
# 수        74
# 예측       73
# 구축       66
# 확보       66
# 알고리즘     65
# 모델       61
# 활용       57
# 수집       56
# 기술       53
# 영상       52
# 등        51
# 검증       47
# 시스템      44
# 정보       42
# 호흡음      42
# 자료       39
# 연구       39
# 학습       39
# 치아       37
# 투석       35
# 프로그램     31
# 치료       31
# 사용       31
# dtype: int64
